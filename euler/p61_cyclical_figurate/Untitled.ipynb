# %% [markdown]
# # Problem Statement
#
# Triangle, square, pentagonal, hexagonal, heptagonal, and octagonal numbers are all figurate (polygonal) numbers and are generated by the following formulae:
#
# Triangle	 	P3,n=n(n+1)/2	 	1, 3, 6, 10, 15, ...
#
# Square	 	P4,n=n2	 	1, 4, 9, 16, 25, ...
#
# Pentagonal	 	P5,n=n(3n−1)/2	 	1, 5, 12, 22, 35, ...
#
# Hexagonal	 	P6,n=n(2n−1)	 	1, 6, 15, 28, 45, ...
#
# Heptagonal	 	P7,n=n(5n−3)/2	 	1, 7, 18, 34, 55, ...
#
# Octagonal	 	P8,n=n(3n−2)	 	1, 8, 21, 40, 65, ...
#
# The ordered set of three 4-digit numbers: 8128, 2882, 8281, has three interesting properties.
#
# The set is cyclic, in that the last two digits of each number is the first two digits of the next number (including the last number with the first).
# Each polygonal type: triangle (P3,127=8128), square (P4,91=8281), and pentagonal (P5,44=2882), is represented by a different number in the set.
# This is the only set of 4-digit numbers with this property.
# Find the sum of the only ordered set of six cyclic 4-digit numbers for which each polygonal type: triangle, square, pentagonal, hexagonal, heptagonal, and octagonal, is represented by a different number in the set.

# %% [markdown]
# ## Graph Theory?
#
# First some function definitions, we'll need to generate numbers to test with:

# %%
def triangle(n):
    return int(n * (n + 1) / 2)

def square(n):
    return n * n

def pentagonal(n):
    return int(n * (3 * n - 1) / 2)

def hexagonal(n):
    return n * (2 * n - 1)

def heptagonal(n):
    return int(n * (5 * n - 3) / 2)

def octagonal(n):
    return n * (3 * n - 2)

funks = [
    ("triangle", triangle),
    ("square", square),
    ("pentagonal", pentagonal),
    ("hexagonal", hexagonal),
    ("heptagonal", heptagonal),
    ("octagonal", octagonal)
]

# Quick check all our functions
for name, func in funks:
    print(name, end=" ")
    for i in range(1, 5):
        print(f"{i}: {func(i)}", end=" ")
    print()
# Out:
# triangle 1: 1 2: 3 3: 6 4: 10
# square 1: 1 2: 4 3: 9 4: 16
# pentagonal 1: 1 2: 5 3: 12 4: 22
# hexagonal 1: 1 2: 6 3: 15 4: 28
# heptagonal 1: 1 2: 7 3: 18 4: 34
# octagonal 1: 1 2: 8 3: 21 4: 40

# %% [markdown]
# Then for each type of number we construct a set of all four digit numbers of that type.

# %%
sets = {}
for name, func in funks:
    sets[name] = set()
    i = 1
    val = func(i)
    while val <= 9999:
        if val >= 1000:
            sets[name].add(val)
        i += 1
        val = func(i)

# %% [markdown]
# This is a lot of connections to deal with, so we can make it easier by pruning impossible values. Any number that has a 0 in the tens place won't be valid because it would point to a 3 digit number. Also we should remove numbers that exist in multiple sets **I think?**

# %%
import collections

for name, s in sets.items():
    r = []
    for n in s:
        if str(n)[2] == "0":
            r.append(n)
    for n in r:
        s.remove(n)

# Remove duplicates...?
# removals = collections.defaultdict(set)
# for from_name in names:
#     for to_name in names:
#         if from_name == to_name:
#             continue
#         for a in sets[from_name]:
#             for b in sets[to_name]:
#                 if a == b:
#                     removals[from_name].add(a)
#                     removals[to_name].add(a)
            
# for name, s in removals.items():
#     for val in s:
#         sets[name].remove(val)

# %% [markdown]
# Then we construct a giant graph of all the numbers and which other numbers they point to. We ignore connections within the same group.

# %%
from pprint import pprint

names = list(sets.keys())
edges = {}

def is_cyclic(a, b):
    return str(a)[2:] == str(b)[:2]

for from_name in names:
    edges[from_name] = {}
    for to_name in names:
        if from_name == to_name:
            continue
        for a in sets[from_name]:
            if a not in edges[from_name]:
                edges[from_name][a] = {}
            for b in sets[to_name]:
                if not is_cyclic(a, b):
                    continue
                if to_name not in edges[from_name][a]:
                    edges[from_name][a][to_name] = []
                edges[from_name][a][to_name].append(b)
pprint(edges)
# Out:
# {'heptagonal': {1071: {'hexagonal': [7140], 'triangle': [7140]},
#                 1177: {'pentagonal': [7740],
#                        'square': [7744],
#                        'triangle': [7750]},
#                 1288: {'pentagonal': [8855], 'square': [8836]},
#                 1525: {'hexagonal': [2556], 'triangle': [2556]},
#                 1651: {'hexagonal': [5151],
#                        'pentagonal': [5192],
#                        'square': [5184],
#                        'triangle': [5151]},
#                 1782: {'square': [8281], 'triangle': [8256]},
#                 1918: {'hexagonal': [1891],
#                        'octagonal': [1825],
#                        'pentagonal': [1820],
#                        'square': [1849],
#                        'triangle': [1830, 1891]},
#                 2059: {'hexagonal': [5995],
#                        'octagonal': [5985],
#                        'pentagonal': [5922],
#                        'square': [5929],
#                        'triangle': [5995]},
#                 2356: {'square': [5625], 'triangle': [5671]},
#                 2512: {'hexagonal': [1225],
#                        'octagonal': [1281],
#                        'pentagonal': [1247],
#                        'square': [1296, 1225],
#                        'triangle': [1225, 1275]},
#                 2673: {'hexagonal': [7381],
#                        'pentagonal': [7315],
#                        'square': [7396],
#                        'triangle': [7381]},
#                 2839: {'square': [3969], 'triangle': [3916]},
#                 3010: {'hexagonal': [1035],
#                        'octagonal': [1045],
#                        'pentagonal': [1080],
#                        'square': [1024, 1089],
#                        'triangle': [1035, 1081]},
#                 3186: {'hexagonal': [8646],
#                        'octagonal': [8640],
#                        'pentagonal': [8626],
#                        'square': [8649],
#                        'triangle': [8646]},
#                 3367: {'square': [6724], 'triangle': [6786]},
#                 3553: {'hexagonal': [5356],
#                        'pentagonal': [5370],
#                        'square': [5329],
#                        'triangle': [5356]},
#                 3744: {'octagonal': [4485],
#                        'square': [4489],
#                        'triangle': [4465]},
#                 3940: {'octagonal': [4033],
#                        'pentagonal': [4030],
#                        'square': [4096],
#                        'triangle': [4095]},
#                 4141: {'hexagonal': [4186],
#                        'pentagonal': [4187],
#                        'triangle': [4186]},
#                 4347: {'hexagonal': [4753],
#                        'octagonal': [4720],
#                        'square': [4761],
#                        'triangle': [4753]},
#                 4558: {'triangle': [5886]},
#                 4774: {},
#                 4995: {'pentagonal': [9560], 'triangle': [9591]},
#                 5221: {'hexagonal': [2145],
#                        'octagonal': [2133],
#                        'pentagonal': [2147],
#                        'square': [2116],
#                        'triangle': [2145]},
#                 5452: {'triangle': [5253]},
#                 5688: {'pentagonal': [8855], 'square': [8836]},
#                 5929: {'square': [2916], 'triangle': [2926]},
#                 6175: {'pentagonal': [7526], 'square': [7569]},
#                 6426: {'octagonal': [2640],
#                        'pentagonal': [2625],
#                        'triangle': [2628]},
#                 6682: {'square': [8281], 'triangle': [8256]},
#                 6943: {'hexagonal': [4371],
#                        'pentagonal': [4347],
#                        'square': [4356],
#                        'triangle': [4371]},
#                 7480: {},
#                 7756: {'square': [5625], 'triangle': [5671]},
#                 8037: {'pentagonal': [3725],
#                        'square': [3721],
#                        'triangle': [3741]},
#                 8323: {'pentagonal': [2380], 'triangle': [2346]},
#                 8614: {'hexagonal': [1431],
#                        'pentagonal': [1426],
#                        'square': [1444],
#                        'triangle': [1431, 1485]},
#                 8910: {'hexagonal': [1035],
#                        'octagonal': [1045],
#                        'pentagonal': [1080],
#                        'square': [1024, 1089],
#                        'triangle': [1035, 1081]},
#                 9211: {'hexagonal': [1128],
#                        'octagonal': [1160],
#                        'pentagonal': [1162],
#                        'square': [1156],
#                        'triangle': [1128, 1176]},
#                 9517: {'hexagonal': [1770],
#                        'pentagonal': [1717],
#                        'square': [1764],
#                        'triangle': [1711, 1770]},
#                 9828: {'hexagonal': [2850],
#                        'octagonal': [2821],
#                        'pentagonal': [2882],
#                        'triangle': [2850]}},
#  'hexagonal': {1035: {'heptagonal': [3553],
#                       'pentagonal': [3577],
#                       'triangle': [3570]},
#                1128: {'heptagonal': [2839],
#                       'octagonal': [2821],
#                       'pentagonal': [2882],
#                       'triangle': [2850]},
#                1225: {'heptagonal': [2512], 'triangle': [2556]},
#                1326: {'heptagonal': [2673],
#                       'octagonal': [2640],
#                       'pentagonal': [2625],
#                       'triangle': [2628]},
#                1431: {'heptagonal': [3186],
#                       'pentagonal': [3151],
#                       'square': [3136],
#                       'triangle': [3160]},
#                1540: {'octagonal': [4033],
#                       'pentagonal': [4030],
#                       'square': [4096],
#                       'triangle': [4095]},
#                1653: {'pentagonal': [5370],
#                       'square': [5329],
#                       'triangle': [5356]},
#                1770: {'square': [7056], 'triangle': [7021]},
#                1891: {'triangle': [9180]},
#                2016: {'heptagonal': [1651],
#                       'octagonal': [1680],
#                       'pentagonal': [1617],
#                       'square': [1681],
#                       'triangle': [1653]},
#                2145: {'heptagonal': [4558],
#                       'pentagonal': [4510],
#                       'triangle': [4560]},
#                2278: {'triangle': [7875]},
#                2415: {'heptagonal': [1525],
#                       'octagonal': [1541],
#                       'pentagonal': [1520],
#                       'square': [1521],
#                       'triangle': [1540, 1596]},
#                2556: {'heptagonal': [5688],
#                       'square': [5625],
#                       'triangle': [5671]},
#                2850: {'pentagonal': [5017],
#                       'square': [5041],
#                       'triangle': [5050]},
#                3160: {'square': [6084]},
#                3321: {'octagonal': [2133],
#                       'pentagonal': [2147],
#                       'square': [2116],
#                       'triangle': [2145]},
#                3486: {'heptagonal': [8614],
#                       'octagonal': [8640],
#                       'pentagonal': [8626],
#                       'square': [8649],
#                       'triangle': [8646]},
#                3655: {'pentagonal': [5551], 'triangle': [5565]},
#                3828: {'heptagonal': [2839],
#                       'octagonal': [2821],
#                       'pentagonal': [2882],
#                       'triangle': [2850]},
#                4186: {'heptagonal': [8614],
#                       'octagonal': [8640],
#                       'pentagonal': [8626],
#                       'square': [8649],
#                       'triangle': [8646]},
#                4371: {'triangle': [7140]},
#                4560: {'square': [6084]},
#                4753: {'pentagonal': [5370],
#                       'square': [5329],
#                       'triangle': [5356]},
#                4950: {'pentagonal': [5017],
#                       'square': [5041],
#                       'triangle': [5050]},
#                5151: {'pentagonal': [5192],
#                       'square': [5184],
#                       'triangle': [5151]},
#                5356: {'heptagonal': [5688],
#                       'square': [5625],
#                       'triangle': [5671]},
#                5565: {'octagonal': [6533],
#                       'square': [6561],
#                       'triangle': [6555]},
#                5778: {'triangle': [7875]},
#                5995: {'heptagonal': [9517],
#                       'pentagonal': [9560],
#                       'triangle': [9591]},
#                6216: {'heptagonal': [1651],
#                       'octagonal': [1680],
#                       'pentagonal': [1617],
#                       'square': [1681],
#                       'triangle': [1653]},
#                6441: {'heptagonal': [4141],
#                       'pentagonal': [4187],
#                       'triangle': [4186]},
#                6670: {'square': [7056], 'triangle': [7021]},
#                7140: {'octagonal': [4033],
#                       'pentagonal': [4030],
#                       'square': [4096],
#                       'triangle': [4095]},
#                7381: {'pentagonal': [8177], 'triangle': [8128]},
#                7626: {'heptagonal': [2673],
#                       'octagonal': [2640],
#                       'pentagonal': [2625],
#                       'triangle': [2628]},
#                7875: {'pentagonal': [7526], 'square': [7569]},
#                8128: {'heptagonal': [2839],
#                       'octagonal': [2821],
#                       'pentagonal': [2882],
#                       'triangle': [2850]},
#                8385: {'triangle': [8515]},
#                8646: {'pentagonal': [4676],
#                       'square': [4624],
#                       'triangle': [4656]},
#                8911: {'heptagonal': [1177],
#                       'octagonal': [1160],
#                       'pentagonal': [1162],
#                       'square': [1156],
#                       'triangle': [1128, 1176]},
#                9180: {'heptagonal': [8037]},
#                9453: {'pentagonal': [5370],
#                       'square': [5329],
#                       'triangle': [5356]},
#                9730: {'heptagonal': [3010],
#                       'pentagonal': [3015],
#                       'square': [3025],
#                       'triangle': [3081]}},
#  'octagonal': {1045: {'heptagonal': [4558],
#                       'hexagonal': [4560],
#                       'pentagonal': [4510],
#                       'triangle': [4560]},
#                1160: {'square': [6084]},
#                1281: {'hexagonal': [8128],
#                       'pentagonal': [8177],
#                       'triangle': [8128]},
#                1541: {'heptagonal': [4141],
#                       'hexagonal': [4186],
#                       'pentagonal': [4187],
#                       'triangle': [4186]},
#                1680: {'heptagonal': [8037]},
#                1825: {'heptagonal': [2512],
#                       'hexagonal': [2556],
#                       'triangle': [2556]},
#                1976: {'hexagonal': [7626], 'triangle': [7626]},
#                2133: {'heptagonal': [3367],
#                       'hexagonal': [3321],
#                       'square': [3364],
#                       'triangle': [3321]},
#                2296: {},
#                2465: {'square': [6561], 'triangle': [6555]},
#                2640: {'pentagonal': [4030],
#                       'square': [4096],
#                       'triangle': [4095]},
#                2821: {'hexagonal': [2145],
#                       'pentagonal': [2147],
#                       'square': [2116],
#                       'triangle': [2145]},
#                3816: {'heptagonal': [1651],
#                       'hexagonal': [1653],
#                       'pentagonal': [1617],
#                       'square': [1681],
#                       'triangle': [1653]},
#                4033: {'heptagonal': [3367],
#                       'hexagonal': [3321],
#                       'square': [3364],
#                       'triangle': [3321]},
#                4256: {'heptagonal': [5688],
#                       'square': [5625],
#                       'triangle': [5671]},
#                4485: {'triangle': [8515]},
#                4720: {'heptagonal': [2059],
#                       'hexagonal': [2016],
#                       'pentagonal': [2035],
#                       'square': [2025],
#                       'triangle': [2080, 2016]},
#                4961: {'heptagonal': [6175], 'pentagonal': [6112]},
#                5461: {'heptagonal': [6175], 'pentagonal': [6112]},
#                5720: {'heptagonal': [2059],
#                       'hexagonal': [2016],
#                       'pentagonal': [2035],
#                       'square': [2025],
#                       'triangle': [2080, 2016]},
#                5985: {'triangle': [8515]},
#                6256: {'heptagonal': [5688],
#                       'square': [5625],
#                       'triangle': [5671]},
#                6533: {'heptagonal': [3367],
#                       'hexagonal': [3321],
#                       'square': [3364],
#                       'triangle': [3321]},
#                6816: {'heptagonal': [1651],
#                       'hexagonal': [1653],
#                       'pentagonal': [1617],
#                       'square': [1681],
#                       'triangle': [1653]},
#                8321: {'hexagonal': [2145],
#                       'pentagonal': [2147],
#                       'square': [2116],
#                       'triangle': [2145]},
#                8640: {'pentagonal': [4030],
#                       'square': [4096],
#                       'triangle': [4095]},
#                8965: {'square': [6561], 'triangle': [6555]},
#                9296: {},
#                9633: {'heptagonal': [3367],
#                       'hexagonal': [3321],
#                       'square': [3364],
#                       'triangle': [3321]},
#                9976: {'hexagonal': [7626], 'triangle': [7626]}},
#  'pentagonal': {1080: {'heptagonal': [8037]},
#                 1162: {'hexagonal': [6216],
#                        'octagonal': [6256],
#                        'square': [6241],
#                        'triangle': [6216]},
#                 1247: {'heptagonal': [4774],
#                        'hexagonal': [4753],
#                        'octagonal': [4720],
#                        'square': [4761],
#                        'triangle': [4753]},
#                 1335: {'heptagonal': [3553], 'triangle': [3570]},
#                 1426: {'heptagonal': [2673],
#                        'octagonal': [2640],
#                        'triangle': [2628]},
#                 1520: {'heptagonal': [2059],
#                        'hexagonal': [2016],
#                        'square': [2025],
#                        'triangle': [2080, 2016]},
#                 1617: {'heptagonal': [1782],
#                        'hexagonal': [1770],
#                        'square': [1764],
#                        'triangle': [1711, 1770]},
#                 1717: {'heptagonal': [1782],
#                        'hexagonal': [1770],
#                        'square': [1764],
#                        'triangle': [1711, 1770]},
#                 1820: {'heptagonal': [2059],
#                        'hexagonal': [2016],
#                        'square': [2025],
#                        'triangle': [2080, 2016]},
#                 1926: {'heptagonal': [2673],
#                        'octagonal': [2640],
#                        'triangle': [2628]},
#                 2035: {'heptagonal': [3553], 'triangle': [3570]},
#                 2147: {'heptagonal': [4774],
#                        'hexagonal': [4753],
#                        'octagonal': [4720],
#                        'square': [4761],
#                        'triangle': [4753]},
#                 2262: {'hexagonal': [6216],
#                        'octagonal': [6256],
#                        'square': [6241],
#                        'triangle': [6216]},
#                 2380: {'heptagonal': [8037]},
#                 2625: {'heptagonal': [2512],
#                        'hexagonal': [2556],
#                        'triangle': [2556]},
#                 2752: {'heptagonal': [5221], 'triangle': [5253]},
#                 2882: {'square': [8281], 'triangle': [8256]},
#                 3015: {'heptagonal': [1525],
#                        'hexagonal': [1540],
#                        'octagonal': [1541],
#                        'square': [1521],
#                        'triangle': [1540, 1596]},
#                 3151: {'hexagonal': [5151],
#                        'square': [5184],
#                        'triangle': [5151]},
#                 3290: {'square': [9025], 'triangle': [9045]},
#                 3432: {'square': [3249], 'triangle': [3240]},
#                 3577: {'heptagonal': [7756],
#                        'square': [7744],
#                        'triangle': [7750]},
#                 3725: {'heptagonal': [2512],
#                        'hexagonal': [2556],
#                        'triangle': [2556]},
#                 3876: {'hexagonal': [7626], 'triangle': [7626]},
#                 4030: {'heptagonal': [3010],
#                        'square': [3025],
#                        'triangle': [3081]},
#                 4187: {'triangle': [8778]},
#                 4347: {'heptagonal': [4774],
#                        'hexagonal': [4753],
#                        'octagonal': [4720],
#                        'square': [4761],
#                        'triangle': [4753]},
#                 4510: {'heptagonal': [1071],
#                        'hexagonal': [1035],
#                        'octagonal': [1045],
#                        'square': [1024, 1089],
#                        'triangle': [1035, 1081]},
#                 4676: {'hexagonal': [7626], 'triangle': [7626]},
#                 4845: {'heptagonal': [4558],
#                        'hexagonal': [4560],
#                        'triangle': [4560]},
#                 5017: {'heptagonal': [1782],
#                        'hexagonal': [1770],
#                        'square': [1764],
#                        'triangle': [1711, 1770]},
#                 5192: {'heptagonal': [9211],
#                        'octagonal': [9296],
#                        'square': [9216]},
#                 5370: {'square': [7056], 'triangle': [7021]},
#                 5551: {'hexagonal': [5151],
#                        'square': [5184],
#                        'triangle': [5151]},
#                 5735: {'heptagonal': [3553], 'triangle': [3570]},
#                 5922: {'hexagonal': [2278],
#                        'octagonal': [2296],
#                        'triangle': [2211, 2278]},
#                 6112: {'heptagonal': [1288],
#                        'hexagonal': [1225],
#                        'octagonal': [1281],
#                        'square': [1296, 1225],
#                        'triangle': [1225, 1275]},
#                 7315: {'heptagonal': [1525],
#                        'hexagonal': [1540],
#                        'octagonal': [1541],
#                        'square': [1521],
#                        'triangle': [1540, 1596]},
#                 7526: {'heptagonal': [2673],
#                        'octagonal': [2640],
#                        'triangle': [2628]},
#                 7740: {'octagonal': [4033],
#                        'square': [4096],
#                        'triangle': [4095]},
#                 7957: {'hexagonal': [5778],
#                        'octagonal': [5720],
#                        'square': [5776],
#                        'triangle': [5778]},
#                 8177: {'heptagonal': [7756],
#                        'square': [7744],
#                        'triangle': [7750]},
#                 8626: {'heptagonal': [2673],
#                        'octagonal': [2640],
#                        'triangle': [2628]},
#                 8855: {'hexagonal': [5565], 'triangle': [5565]},
#                 9087: {'triangle': [8778]},
#                 9322: {'hexagonal': [2278],
#                        'octagonal': [2296],
#                        'triangle': [2211, 2278]},
#                 9560: {'square': [6084]}},
#  'square': {1024: {'hexagonal': [2415],
#                    'octagonal': [2465],
#                    'triangle': [2415, 2485]},
#             1089: {'heptagonal': [8910],
#                    'hexagonal': [8911],
#                    'octagonal': [8965],
#                    'triangle': [8911]},
#             1156: {'heptagonal': [5688], 'triangle': [5671]},
#             1225: {'heptagonal': [2512],
#                    'hexagonal': [2556],
#                    'triangle': [2556]},
#             1296: {'octagonal': [9633]},
#             1369: {'heptagonal': [6943]},
#             1444: {'octagonal': [4485], 'triangle': [4465]},
#             1521: {'hexagonal': [2145],
#                    'octagonal': [2133],
#                    'pentagonal': [2147],
#                    'triangle': [2145]},
#             1681: {'hexagonal': [8128],
#                    'pentagonal': [8177],
#                    'triangle': [8128]},
#             1764: {'heptagonal': [6426],
#                    'hexagonal': [6441],
#                    'triangle': [6441]},
#             1849: {'heptagonal': [4995],
#                    'hexagonal': [4950],
#                    'octagonal': [4961],
#                    'triangle': [4950]},
#             1936: {'hexagonal': [3655], 'triangle': [3655]},
#             2025: {'heptagonal': [2512],
#                    'hexagonal': [2556],
#                    'triangle': [2556]},
#             2116: {'heptagonal': [1651],
#                    'hexagonal': [1653],
#                    'octagonal': [1680],
#                    'pentagonal': [1617],
#                    'triangle': [1653]},
#             2916: {'heptagonal': [1651],
#                    'hexagonal': [1653],
#                    'octagonal': [1680],
#                    'pentagonal': [1617],
#                    'triangle': [1653]},
#             3025: {'heptagonal': [2512],
#                    'hexagonal': [2556],
#                    'triangle': [2556]},
#             3136: {'hexagonal': [3655], 'triangle': [3655]},
#             3249: {'heptagonal': [4995],
#                    'hexagonal': [4950],
#                    'octagonal': [4961],
#                    'triangle': [4950]},
#             3364: {'heptagonal': [6426],
#                    'hexagonal': [6441],
#                    'triangle': [6441]},
#             3481: {'hexagonal': [8128],
#                    'pentagonal': [8177],
#                    'triangle': [8128]},
#             3721: {'hexagonal': [2145],
#                    'octagonal': [2133],
#                    'pentagonal': [2147],
#                    'triangle': [2145]},
#             3844: {'octagonal': [4485], 'triangle': [4465]},
#             3969: {'heptagonal': [6943]},
#             4096: {'octagonal': [9633]},
#             4225: {'heptagonal': [2512],
#                    'hexagonal': [2556],
#                    'triangle': [2556]},
#             4356: {'heptagonal': [5688], 'triangle': [5671]},
#             4489: {'heptagonal': [8910],
#                    'hexagonal': [8911],
#                    'octagonal': [8965],
#                    'triangle': [8911]},
#             4624: {'hexagonal': [2415],
#                    'octagonal': [2465],
#                    'triangle': [2415, 2485]},
#             4761: {'heptagonal': [6175], 'pentagonal': [6112]},
#             5041: {'heptagonal': [4141],
#                    'hexagonal': [4186],
#                    'pentagonal': [4187],
#                    'triangle': [4186]},
#             5184: {},
#             5329: {'triangle': [2926]},
#             5476: {'hexagonal': [7626], 'triangle': [7626]},
#             5625: {'heptagonal': [2512],
#                    'hexagonal': [2556],
#                    'triangle': [2556]},
#             5776: {'hexagonal': [7626], 'triangle': [7626]},
#             5929: {'triangle': [2926]},
#             6084: {},
#             6241: {'heptagonal': [4141],
#                    'hexagonal': [4186],
#                    'pentagonal': [4187],
#                    'triangle': [4186]},
#             6561: {'heptagonal': [6175], 'pentagonal': [6112]},
#             6724: {'hexagonal': [2415],
#                    'octagonal': [2465],
#                    'triangle': [2415, 2485]},
#             6889: {'heptagonal': [8910],
#                    'hexagonal': [8911],
#                    'octagonal': [8965],
#                    'triangle': [8911]},
#             7056: {'heptagonal': [5688], 'triangle': [5671]},
#             7225: {'heptagonal': [2512],
#                    'hexagonal': [2556],
#                    'triangle': [2556]},
#             7396: {'octagonal': [9633]},
#             7569: {'heptagonal': [6943]},
#             7744: {'octagonal': [4485], 'triangle': [4465]},
#             7921: {'hexagonal': [2145],
#                    'octagonal': [2133],
#                    'pentagonal': [2147],
#                    'triangle': [2145]},
#             8281: {'hexagonal': [8128],
#                    'pentagonal': [8177],
#                    'triangle': [8128]},
#             8464: {'heptagonal': [6426],
#                    'hexagonal': [6441],
#                    'triangle': [6441]},
#             8649: {'heptagonal': [4995],
#                    'hexagonal': [4950],
#                    'octagonal': [4961],
#                    'triangle': [4950]},
#             8836: {'hexagonal': [3655], 'triangle': [3655]},
#             9025: {'heptagonal': [2512],
#                    'hexagonal': [2556],
#                    'triangle': [2556]},
#             9216: {'heptagonal': [1651],
#                    'hexagonal': [1653],
#                    'octagonal': [1680],
#                    'pentagonal': [1617],
#                    'triangle': [1653]}},
#  'triangle': {1035: {'heptagonal': [3553], 'pentagonal': [3577]},
#               1081: {'hexagonal': [8128], 'pentagonal': [8177]},
#               1128: {'heptagonal': [2839],
#                      'hexagonal': [2850],
#                      'octagonal': [2821],
#                      'pentagonal': [2882]},
#               1176: {'hexagonal': [7626]},
#               1225: {'heptagonal': [2512], 'hexagonal': [2556]},
#               1275: {'pentagonal': [7526], 'square': [7569]},
#               1326: {'heptagonal': [2673],
#                      'octagonal': [2640],
#                      'pentagonal': [2625]},
#               1378: {'hexagonal': [7875]},
#               1431: {'heptagonal': [3186],
#                      'hexagonal': [3160],
#                      'pentagonal': [3151],
#                      'square': [3136]},
#               1485: {},
#               1540: {'octagonal': [4033],
#                      'pentagonal': [4030],
#                      'square': [4096]},
#               1596: {'octagonal': [9633]},
#               1653: {'hexagonal': [5356],
#                      'pentagonal': [5370],
#                      'square': [5329]},
#               1711: {'heptagonal': [1177],
#                      'hexagonal': [1128],
#                      'octagonal': [1160],
#                      'pentagonal': [1162],
#                      'square': [1156]},
#               1770: {'square': [7056]},
#               1830: {'heptagonal': [3010],
#                      'pentagonal': [3015],
#                      'square': [3025]},
#               1891: {'hexagonal': [9180]},
#               1953: {'hexagonal': [5356],
#                      'pentagonal': [5370],
#                      'square': [5329]},
#               2016: {'heptagonal': [1651],
#                      'hexagonal': [1653],
#                      'octagonal': [1680],
#                      'pentagonal': [1617],
#                      'square': [1681]},
#               2080: {'heptagonal': [8037]},
#               2145: {'heptagonal': [4558],
#                      'hexagonal': [4560],
#                      'pentagonal': [4510]},
#               2211: {'heptagonal': [1177],
#                      'hexagonal': [1128],
#                      'octagonal': [1160],
#                      'pentagonal': [1162],
#                      'square': [1156]},
#               2278: {'hexagonal': [7875]},
#               2346: {'pentagonal': [4676], 'square': [4624]},
#               2415: {'heptagonal': [1525],
#                      'hexagonal': [1540],
#                      'octagonal': [1541],
#                      'pentagonal': [1520],
#                      'square': [1521]},
#               2485: {},
#               2556: {'heptagonal': [5688], 'square': [5625]},
#               2628: {'heptagonal': [2839],
#                      'hexagonal': [2850],
#                      'octagonal': [2821],
#                      'pentagonal': [2882]},
#               2775: {'pentagonal': [7526], 'square': [7569]},
#               2850: {'pentagonal': [5017], 'square': [5041]},
#               2926: {'heptagonal': [2673],
#                      'octagonal': [2640],
#                      'pentagonal': [2625]},
#               3081: {'hexagonal': [8128], 'pentagonal': [8177]},
#               3160: {'square': [6084]},
#               3240: {'octagonal': [4033],
#                      'pentagonal': [4030],
#                      'square': [4096]},
#               3321: {'hexagonal': [2145],
#                      'octagonal': [2133],
#                      'pentagonal': [2147],
#                      'square': [2116]},
#               3486: {'heptagonal': [8614],
#                      'hexagonal': [8646],
#                      'octagonal': [8640],
#                      'pentagonal': [8626],
#                      'square': [8649]},
#               3570: {'square': [7056]},
#               3655: {'hexagonal': [5565], 'pentagonal': [5551]},
#               3741: {'heptagonal': [4141],
#                      'hexagonal': [4186],
#                      'pentagonal': [4187]},
#               3828: {'heptagonal': [2839],
#                      'hexagonal': [2850],
#                      'octagonal': [2821],
#                      'pentagonal': [2882]},
#               3916: {'heptagonal': [1651],
#                      'hexagonal': [1653],
#                      'octagonal': [1680],
#                      'pentagonal': [1617],
#                      'square': [1681]},
#               4095: {'heptagonal': [9517], 'pentagonal': [9560]},
#               4186: {'heptagonal': [8614],
#                      'hexagonal': [8646],
#                      'octagonal': [8640],
#                      'pentagonal': [8626],
#                      'square': [8649]},
#               4278: {'hexagonal': [7875]},
#               4371: {'hexagonal': [7140]},
#               4465: {'octagonal': [6533], 'square': [6561]},
#               4560: {'square': [6084]},
#               4656: {'heptagonal': [5688], 'square': [5625]},
#               4753: {'hexagonal': [5356],
#                      'pentagonal': [5370],
#                      'square': [5329]},
#               4851: {'hexagonal': [5151],
#                      'pentagonal': [5192],
#                      'square': [5184]},
#               4950: {'pentagonal': [5017], 'square': [5041]},
#               5050: {'pentagonal': [5017], 'square': [5041]},
#               5151: {'hexagonal': [5151],
#                      'pentagonal': [5192],
#                      'square': [5184]},
#               5253: {'hexagonal': [5356],
#                      'pentagonal': [5370],
#                      'square': [5329]},
#               5356: {'heptagonal': [5688], 'square': [5625]},
#               5460: {'square': [6084]},
#               5565: {'octagonal': [6533], 'square': [6561]},
#               5671: {'hexagonal': [7140]},
#               5778: {'hexagonal': [7875]},
#               5886: {'heptagonal': [8614],
#                      'hexagonal': [8646],
#                      'octagonal': [8640],
#                      'pentagonal': [8626],
#                      'square': [8649]},
#               5995: {'heptagonal': [9517], 'pentagonal': [9560]},
#               6216: {'heptagonal': [1651],
#                      'hexagonal': [1653],
#                      'octagonal': [1680],
#                      'pentagonal': [1617],
#                      'square': [1681]},
#               6328: {'heptagonal': [2839],
#                      'hexagonal': [2850],
#                      'octagonal': [2821],
#                      'pentagonal': [2882]},
#               6441: {'heptagonal': [4141],
#                      'hexagonal': [4186],
#                      'pentagonal': [4187]},
#               6555: {'hexagonal': [5565], 'pentagonal': [5551]},
#               6670: {'square': [7056]},
#               6786: {'heptagonal': [8614],
#                      'hexagonal': [8646],
#                      'octagonal': [8640],
#                      'pentagonal': [8626],
#                      'square': [8649]},
#               7021: {'hexagonal': [2145],
#                      'octagonal': [2133],
#                      'pentagonal': [2147],
#                      'square': [2116]},
#               7140: {'octagonal': [4033],
#                      'pentagonal': [4030],
#                      'square': [4096]},
#               7260: {'square': [6084]},
#               7381: {'hexagonal': [8128], 'pentagonal': [8177]},
#               7626: {'heptagonal': [2673],
#                      'octagonal': [2640],
#                      'pentagonal': [2625]},
#               7750: {'pentagonal': [5017], 'square': [5041]},
#               7875: {'pentagonal': [7526], 'square': [7569]},
#               8128: {'heptagonal': [2839],
#                      'hexagonal': [2850],
#                      'octagonal': [2821],
#                      'pentagonal': [2882]},
#               8256: {'heptagonal': [5688], 'square': [5625]},
#               8385: {},
#               8515: {'heptagonal': [1525],
#                      'hexagonal': [1540],
#                      'octagonal': [1541],
#                      'pentagonal': [1520],
#                      'square': [1521]},
#               8646: {'pentagonal': [4676], 'square': [4624]},
#               8778: {'hexagonal': [7875]},
#               8911: {'heptagonal': [1177],
#                      'hexagonal': [1128],
#                      'octagonal': [1160],
#                      'pentagonal': [1162],
#                      'square': [1156]},
#               9045: {'heptagonal': [4558],
#                      'hexagonal': [4560],
#                      'pentagonal': [4510]},
#               9180: {'heptagonal': [8037]},
#               9316: {'heptagonal': [1651],
#                      'hexagonal': [1653],
#                      'octagonal': [1680],
#                      'pentagonal': [1617],
#                      'square': [1681]},
#               9453: {'hexagonal': [5356],
#                      'pentagonal': [5370],
#                      'square': [5329]},
#               9591: {'hexagonal': [9180]},
#               9730: {'heptagonal': [3010],
#                      'pentagonal': [3015],
#                      'square': [3025]},
#               9870: {'square': [7056]}}}

# %% [markdown]
# This is a massive amount of edges, and naturally someone has written a efficient algorithm to do this, but I'mma just brute force it. We can do this by using a backtracking recursive algorithm. Since we know that one node from each type must be included, we can simply go through each triangle node, and assume that it is in the final loop. Then for each edge we make the same assumption until we reach a contradiction.

# %%
names = list(sets.keys())

def find_chain(node, node_type, types_considered=[], chain=[]):
    if not types_considered:
        types_considered = [node_type]
    if not chain:
        chain=[(node, node_type)]
        
    if len(chain) == 6:
        return chain
    
    max_chain = chain
    for n in names:
        if n in types_considered:
            continue
        if n not in edges[node_type][node]:
            continue
        for val in edges[node_type][node][n]:
            c = find_chain(val, n, types_considered=types_considered + [n], chain=chain + [(val, n)])
            # Make sure to check for chains that loop back to the start.
            if len(c) >= len(max_chain) and is_cyclic(c[-1][0], c[0][0]):
                max_chain = c
        
    return max_chain

max_chain = []
for node in edges['heptagonal'].keys():
    chain = find_chain(node, 'heptagonal')
    if len(chain) > len(max_chain):
        max_chain = chain
        
print(max_chain)
print(sum([item[0] for item in max_chain]))
# Out:
# [(2512, 'heptagonal'), (1281, 'octagonal'), (8128, 'hexagonal'), (2882, 'pentagonal'), (8256, 'triangle'), (5625, 'square')]
# 28684
